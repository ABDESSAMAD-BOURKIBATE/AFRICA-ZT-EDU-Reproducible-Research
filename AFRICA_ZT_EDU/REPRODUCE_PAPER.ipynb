# %% [markdown]
# # AFRICA-ZT-EDU — Reproduce the Paper
# This notebook validates and reproduces the computational artifact supporting the AFRICA-ZT-EDU research article. All experimental records are synthetic.

# %% [markdown]
# ## 1. Environment
# Install the exact Python dependencies recorded by the artifact.

# %%
# %pip install -r requirements.txt

# %% [markdown]
# ## 2. Quick validation
# Run this first. It uses a reduced request count and benchmark scale to verify that the environment, scripts, and output paths work.

# %%
# !python run_all.py --quick

# %% [markdown]
# ## 3. Inspect quick outputs

# %%
from pathlib import Path
import pandas as pd
p = Path('renku_quick/data/results_summary.csv')
display(pd.read_csv(p) if p.exists() else 'Quick result file not found')

# %% [markdown]
# ## 4. Full published-scale reproduction
# This launches the declared 30-seed / 3,000,000-request policy experiment, the benchmark, and figure regeneration. Runtime depends on the Renku compute class.

# %%
# Uncomment when you are ready to run the complete reproduction.
# !python run_all.py --full

# %% [markdown]
# ## 5. Published-scale results already included in the repository
# The repository contains the recorded outputs used in the article. Use the full run above to independently regenerate them.

# %%
display(pd.read_csv('data/results_summary.csv'))
display(pd.read_csv('data/policy_staleness.csv'))
display(pd.read_csv('data/dp_utility.csv'))
display(pd.read_csv('results/benchmark_summary.csv'))
